# %%
import keras
import tensorflow as tf
import gdal
import os
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
from keras_unet.models import custom_unet, satellite_unet
from keras_unet.metrics import iou, iou_thresholded
from keras_unet.losses import jaccard_distance
from keras_unet.utils import plot_segm_history

# %%
image_dir = Path(r'/media/hkropp/research/milkweed/training/img_g22')
milk_dir = Path(r'/media/hkropp/research/milkweed/training/masks_g22')

# %%
def make_path(img_dir, prefix, number):
    return os.path.join(img_dir, f"{prefix}_{number}.tif")

# %%
def img_number(fpath: str) -> int:
    return int(os.path.splitext(os.path.split(fpath)[1])[0].split('_')[-1])

# %%
import typing as t

def load_image_rgb(path: str, shape: t.Tuple[int,int,int], dtype) -> np.ndarray:
    image = np.zeros(shape = shape, dtype=dtype)
    ds= gdal.Open(path, gdal.GA_ReadOnly)
    for i in (1, 2, 3):
        image[:, :, i-1] = ds.GetRasterBand(i).ReadAsArray()
    return image

# %%
def load_image(path: str) -> np.ndarray:
    ds = gdal.Open(path, gdal.GA_ReadOnly)
    return ds.GetRasterBand(1).ReadAsArray()

# %%
def load_stack_rgb(shape, dtype, img_dir, prefix):
    stack = np.zeros(shape = shape, dtype = dtype)
    for i in range(shape[0]):
        image_path = make_path(img_dir, prefix, i + 1)
        # subsets for rgb bands only
        stack[i, :, :, :] = load_image_rgb(image_path, (shape[1], shape[2], shape[3]), dtype)
    return stack

# need to skip when there is no mask
# loads single band mask
def load_stack_safely(shape, dtype, img_dir, prefix):
    stack = np.zeros(shape = shape, dtype = dtype)
    for i in range(shape[0]):
        image_path = make_path(img_dir, prefix, i + 1)
        if not os.path.isfile(image_path):
            print("skipping", image_path)
            continue
        stack[i, :, :] = load_image(image_path)
    return stack

# %%
# training total data size
I = 377
# image dim 1
N = 256
# image dim 2
M = 256
# number of image bands
L = 3
# number of classes
V = 1

# %%
train_images = load_stack_rgb((I, N, M, L), np.int8, image_dir, "img")
train_images_R = train_images.reshape(I, N, M, L)

# %%
train_images_R.shape
# Out:
# (377, 256, 256, 3)

# %%
test = gdal.Open(r'/media/hkropp/research/milkweed/training/img_g22/img_1.tif', gdal.GA_ReadOnly)

# %%
test
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f302f4a3a20> >

# %%
plt.imshow(test.GetRasterBand(3).ReadAsArray())

# %%
milk_mask = load_stack_safely((I, N, M), np.int8, milk_dir, "milkweed")
# Out:
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_1.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_2.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_3.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_4.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_5.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_6.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_7.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_8.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_9.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_10.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_11.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_12.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_13.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_15.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_18.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_19.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_21.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_22.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_23.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_24.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_25.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_26.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_27.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_28.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_29.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_30.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_31.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_32.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_34.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_36.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_37.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_38.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_40.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_41.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_42.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_43.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_44.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_45.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_46.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_47.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_48.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_49.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_50.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_51.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_52.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_53.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_54.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_55.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_56.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_57.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_58.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_60.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_61.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_62.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_63.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_64.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_65.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_66.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_67.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_68.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_69.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_71.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_72.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_73.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_74.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_75.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_76.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_77.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_78.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_79.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_80.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_81.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_82.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_83.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_84.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_85.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_86.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_87.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_88.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_89.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_90.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_91.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_93.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_94.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_95.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_96.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_97.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_98.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_100.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_101.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_103.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_104.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_105.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_106.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_107.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_108.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_109.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_110.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_111.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_113.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_114.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_115.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_117.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_120.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_121.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_122.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_124.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_125.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_126.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_127.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_128.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_129.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_130.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_131.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_132.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_133.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_135.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_136.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_137.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_138.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_139.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_140.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_141.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_142.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_143.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_145.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_146.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_147.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_148.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_150.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_151.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_152.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_153.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_154.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_155.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_156.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_158.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_159.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_160.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_161.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_162.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_163.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_164.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_165.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_166.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_168.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_169.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_170.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_173.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_174.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_175.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_176.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_177.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_178.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_179.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_180.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_182.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_183.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_184.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_185.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_186.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_187.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_189.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_190.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_191.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_192.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_194.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_195.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_196.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_197.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_198.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_199.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_200.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_201.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_204.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_206.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_207.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_209.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_210.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_211.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_212.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_213.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_214.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_215.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_216.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_217.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_218.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_219.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_220.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_221.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_222.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_223.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_224.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_225.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_227.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_228.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_229.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_231.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_232.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_233.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_234.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_235.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_236.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_237.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_238.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_239.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_241.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_242.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_243.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_244.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_245.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_246.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_247.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_248.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_249.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_250.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_251.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_252.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_253.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_254.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_255.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_256.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_257.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_258.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_259.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_260.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_261.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_263.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_264.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_265.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_266.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_267.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_268.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_269.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_270.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_271.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_272.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_273.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_274.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_275.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_276.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_277.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_278.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_279.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_280.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_281.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_282.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_283.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_284.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_285.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_286.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_287.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_288.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_289.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_290.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_291.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_292.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_293.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_294.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_295.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_296.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_297.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_298.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_299.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_300.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_301.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_302.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_303.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_304.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_305.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_306.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_307.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_308.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_309.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_310.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_311.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_312.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_313.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_314.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_315.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_316.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_317.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_318.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_319.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_320.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_321.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_322.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_323.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_324.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_325.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_326.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_327.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_328.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_329.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_330.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_331.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_332.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_333.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_334.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_335.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_336.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_337.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_338.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_339.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_340.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_346.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_353.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_354.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_355.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_359.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_365.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_366.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_368.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_370.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_372.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_374.tif
# skipping /media/hkropp/research/milkweed/training/masks_g22/milkweed_376.tif

# %%
plt.imshow(milk_mask[13, :,:])

# %%
plt.hist(milk_mask[13:,:].flatten())
plt.show()

# %%
# alter unet code from package
from keras_unet import TF
if TF:
    from tensorflow.keras.models import Model
    from tensorflow.keras.layers import ( 
        BatchNormalization, Conv2D, Conv2DTranspose,
        MaxPooling2D, UpSampling2D, Input,
        concatenate
    )
else:    
    from keras.models import Model
    from keras.layers import ( 
        BatchNormalization, Conv2D, Conv2DTranspose,
        MaxPooling2D, UpSampling2D, Input,
        concatenate
    )


def bn_conv_relu(input, filters, bachnorm_momentum, **conv2d_args):
    x = BatchNormalization(momentum=bachnorm_momentum)(input)
    x = Conv2D(filters, **conv2d_args)(x)
    return x

def bn_upconv_relu(input, filters, bachnorm_momentum, **conv2d_trans_args):
    x = BatchNormalization(momentum=bachnorm_momentum)(input)
    x = Conv2DTranspose(filters, **conv2d_trans_args)(x)
    return x

def satellite_unet2(
    input_shape,
    num_classes=1,
    output_activation='sigmoid',
    num_layers=4):

    inputs = Input(input_shape)   
    
    filters = 64
    upconv_filters = 96

    kernel_size = (5,5)
    activation = 'relu'
    strides = (1,1)
    padding = 'same'
    kernel_initializer = 'he_normal'

    conv2d_args = {
        'kernel_size':kernel_size,
        'activation':activation, 
        'strides':strides,
        'padding':padding,
        'kernel_initializer':kernel_initializer
        }

    conv2d_trans_args = {
        'kernel_size':kernel_size,
        'activation':activation, 
        'strides':(2,2),
        'padding':padding,
        'output_padding':(1,1)
        }

    bachnorm_momentum = 0.01

    pool_size = (2,2)
    pool_strides = (2,2)
    pool_padding = 'valid'

    maxpool2d_args = {
        'pool_size':pool_size,
        'strides':pool_strides,
        'padding':pool_padding,
        }
    
    x = Conv2D(filters, **conv2d_args)(inputs)
    c1 = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)    
    x = bn_conv_relu(c1, filters, bachnorm_momentum, **conv2d_args)
    x = MaxPooling2D(**maxpool2d_args)(x)

    down_layers = []

    for l in range(num_layers):
        x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
        x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
        down_layers.append(x)
        x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
        x = MaxPooling2D(**maxpool2d_args)(x)

    x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
    x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
    x = bn_upconv_relu(x, filters, bachnorm_momentum, **conv2d_trans_args)

    for conv in reversed(down_layers):        
        x = concatenate([x, conv])  
        x = bn_conv_relu(x, upconv_filters, bachnorm_momentum, **conv2d_args)
        x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
        x = bn_upconv_relu(x, filters, bachnorm_momentum, **conv2d_trans_args)

    x = concatenate([x, c1])
    x = bn_conv_relu(x, upconv_filters, bachnorm_momentum, **conv2d_args)
    x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
           
    outputs = Conv2D(num_classes, kernel_size=(1,1), strides=(1,1), activation=output_activation, padding='valid') (x)       
    
    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
model = satellite_unet2((N, M, 3), V)

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(),
    loss = "binary_crossentropy",
    metrics = [iou, iou_thresholded],
)

# %%
history = model.fit(train_images_R, milk_mask, epochs = 350)
# Out:
# Epoch 1/350
# 12/12 [==============================] - 107s 8s/step - loss: 0.1920 - iou: 0.0051 - iou_thresholded: 0.0283
# Epoch 2/350
#  4/12 [=========>....................] - ETA: 1:06 - loss: 0.0201 - iou: 0.0249 - iou_thresholded: 1.6433e-04

# %%
plt.plot(history.history['iou'])

# %%
plt.plot(history.history['loss'])

# %%
modelsave_path = Path(r'/media/hkropp/research/milkweed/model/m_k5')

# %%
model.save(modelsave_path)

# %%
Y_pred = model.predict(train_images_R)
# Out:
# 12/12 [==============================] - 39s 3s/step

# %%
from keras_unet.utils import plot_imgs

# milkweed
plot_imgs(
    org_imgs=train_images_R.reshape(I, N, M, 3)[:,:,:,1], 
    mask_imgs=milk_mask[:, :, :], 
    pred_imgs=Y_pred[:, :, :, 0], 
    nm_img_to_plot=20
  )

# %%
milk_mask.shape
# Out:
# (377, 256, 256)

# %%
base_dirP = r'/media/hkropp/research/milkweed/tile_07_22_22'
tiles = os.listdir(base_dirP)

T = len(tiles)

# %%
T
# Out:
# 526

# %%
tiles
# Out:
# ['img851.tif',
#  'img285.tif',
#  'img456.tif',
#  'img19.tif',
#  'img228.tif',
#  'img337.tif',
#  'img382.tif',
#  'img889.tif',
#  'img450.tif',
#  'img298.tif',
#  'img914.tif',
#  'img266.tif',
#  'img698.tif',
#  'img455.tif',
#  'img361.tif',
#  'img820.tif',
#  'img672.tif',
#  'img300.tif',
#  'img137.tif',
#  'img490.tif',
#  'img977.tif',
#  'img113.tif',
#  'img513.tif',
#  'img614.tif',
#  'img255.tif',
#  'img458.tif',
#  'img328.tif',
#  'img208.tif',
#  'img417.tif',
#  'img199.tif',
#  'img484.tif',
#  'img49.tif',
#  'img605.tif',
#  'img362.tif',
#  'img492.tif',
#  'img486.tif',
#  'img860.tif',
#  'img420.tif',
#  'img327.tif',
#  'img707.tif',
#  'img520.tif',
#  'img430.tif',
#  'img525.tif',
#  'img787.tif',
#  'img512.tif',
#  'img144.tif',
#  'img632.tif',
#  'img613.tif',
#  'img521.tif',
#  'img916.tif',
#  'img314.tif',
#  'img52.tif',
#  'img761.tif',
#  'img269.tif',
#  'img646.tif',
#  'img141.tif',
#  'img980.tif',
#  'img481.tif',
#  'img480.tif',
#  'img526.tif',
#  'img263.tif',
#  'img734.tif',
#  'img51.tif',
#  'img462.tif',
#  'img197.tif',
#  'img201.tif',
#  'img233.tif',
#  'img664.tif',
#  'img387.tif',
#  'img235.tif',
#  'img195.tif',
#  'img799.tif',
#  'img429.tif',
#  'img519.tif',
#  'img354.tif',
#  'img324.tif',
#  'img366.tif',
#  'img457.tif',
#  'img483.tif',
#  'img146.tif',
#  'img949.tif',
#  'img262.tif',
#  'img319.tif',
#  'img428.tif',
#  'img569.tif',
#  'img676.tif',
#  'img293.tif',
#  'img766.tif',
#  'img478.tif',
#  'img608.tif',
#  'img110.tif',
#  'img477.tif',
#  'img755.tif',
#  'img419.tif',
#  'img443.tif',
#  'img545.tif',
#  'img267.tif',
#  'img644.tif',
#  'img380.tif',
#  'img463.tif',
#  'img239.tif',
#  'img348.tif',
#  'img576.tif',
#  'img258.tif',
#  'img178.tif',
#  'img725.tif',
#  'img344.tif',
#  'img177.tif',
#  'img541.tif',
#  'img18.tif',
#  'img740.tif',
#  'img790.tif',
#  'img400.tif',
#  'img81.tif',
#  'img226.tif',
#  'img794.tif',
#  'img671.tif',
#  'img272.tif',
#  'img413.tif',
#  'img365.tif',
#  'img260.tif',
#  'img240.tif',
#  'img517.tif',
#  'img353.tif',
#  'img703.tif',
#  'img885.tif',
#  'img346.tif',
#  'img857.tif',
#  'img546.tif',
#  'img542.tif',
#  'img459.tif',
#  'img543.tif',
#  'img410.tif',
#  'img855.tif',
#  'img447.tif',
#  'img351.tif',
#  'img584.tif',
#  'img633.tif',
#  'img394.tif',
#  'img674.tif',
#  'img888.tif',
#  'img732.tif',
#  'img756.tif',
#  'img568.tif',
#  'img378.tif',
#  'img289.tif',
#  'img493.tif',
#  'img673.tif',
#  'img442.tif',
#  'img791.tif',
#  'img616.tif',
#  'img325.tif',
#  'img411.tif',
#  'img649.tif',
#  'img951.tif',
#  'img391.tif',
#  'img538.tif',
#  'img540.tif',
#  'img482.tif',
#  'img733.tif',
#  'img451.tif',
#  'img331.tif',
#  'img229.tif',
#  'img607.tif',
#  'img522.tif',
#  'img388.tif',
#  'img763.tif',
#  'img724.tif',
#  'img422.tif',
#  'img299.tif',
#  'img797.tif',
#  'img730.tif',
#  'img167.tif',
#  'img479.tif',
#  'img978.tif',
#  'img424.tif',
#  'img554.tif',
#  'img611.tif',
#  'img883.tif',
#  'img581.tif',
#  'img414.tif',
#  'img800.tif',
#  'img548.tif',
#  'img173.tif',
#  'img759.tif',
#  'img386.tif',
#  'img609.tif',
#  'img461.tif',
#  'img669.tif',
#  'img606.tif',
#  'img47.tif',
#  'img917.tif',
#  'img230.tif',
#  'img551.tif',
#  'img445.tif',
#  'img617.tif',
#  'img708.tif',
#  'img762.tif',
#  'img168.tif',
#  'img858.tif',
#  'img336.tif',
#  'img409.tif',
#  'img320.tif',
#  'img301.tif',
#  'img636.tif',
#  'img166.tif',
#  'img854.tif',
#  'img114.tif',
#  'img827.tif',
#  'img824.tif',
#  'img731.tif',
#  'img408.tif',
#  'img385.tif',
#  'img427.tif',
#  'img109.tif',
#  'img679.tif',
#  'img290.tif',
#  'img856.tif',
#  'img379.tif',
#  'img136.tif',
#  'img334.tif',
#  'img444.tif',
#  'img395.tif',
#  'img575.tif',
#  'img80.tif',
#  'img557.tif',
#  'img491.tif',
#  'img603.tif',
#  'img950.tif',
#  'img793.tif',
#  'img571.tif',
#  'img426.tif',
#  'img819.tif',
#  'img798.tif',
#  'img667.tif',
#  'img268.tif',
#  'img642.tif',
#  'img50.tif',
#  'img431.tif',
#  'img170.tif',
#  'img291.tif',
#  'img705.tif',
#  'img425.tif',
#  'img210.tif',
#  'img256.tif',
#  'img323.tif',
#  'img295.tif',
#  'img736.tif',
#  'img79.tif',
#  'img376.tif',
#  'img142.tif',
#  'img511.tif',
#  'img116.tif',
#  'img550.tif',
#  'img737.tif',
#  'img670.tif',
#  'img401.tif',
#  'img237.tif',
#  'img638.tif',
#  'img356.tif',
#  'img822.tif',
#  'img322.tif',
#  'img145.tif',
#  'img537.tif',
#  'img364.tif',
#  'img700.tif',
#  'img665.tif',
#  'img610.tif',
#  'img207.tif',
#  'img148.tif',
#  'img261.tif',
#  'img795.tif',
#  'img140.tif',
#  'img570.tif',
#  'img303.tif',
#  'img359.tif',
#  'img78.tif',
#  'img580.tif',
#  'img577.tif',
#  'img552.tif',
#  'img891.tif',
#  'img270.tif',
#  'img138.tif',
#  'img304.tif',
#  'img789.tif',
#  'img296.tif',
#  'img302.tif',
#  'img384.tif',
#  'img111.tif',
#  'img274.tif',
#  'img696.tif',
#  'img572.tif',
#  'img510.tif',
#  'img421.tif',
#  'img544.tif',
#  'img473.tif',
#  'img948.tif',
#  'img523.tif',
#  'img796.tif',
#  'img17.tif',
#  'img981.tif',
#  'img321.tif',
#  'img397.tif',
#  'img287.tif',
#  'img635.tif',
#  'img284.tif',
#  'img739.tif',
#  'img947.tif',
#  'img668.tif',
#  'img169.tif',
#  'img697.tif',
#  'img358.tif',
#  'img77.tif',
#  'img600.tif',
#  'img232.tif',
#  'img639.tif',
#  'img494.tif',
#  'img701.tif',
#  'img587.tif',
#  'img273.tif',
#  'img487.tif',
#  'img330.tif',
#  'img335.tif',
#  'img574.tif',
#  'img115.tif',
#  'img271.tif',
#  'img640.tif',
#  'img788.tif',
#  'img449.tif',
#  'img1011.tif',
#  'img399.tif',
#  'img645.tif',
#  'img432.tif',
#  'img829.tif',
#  'img602.tif',
#  'img412.tif',
#  'img850.tif',
#  'img355.tif',
#  'img516.tif',
#  'img196.tif',
#  'img615.tif',
#  'img585.tif',
#  'img383.tif',
#  'img1041.tif',
#  'img830.tif',
#  'img454.tif',
#  'img225.tif',
#  'img294.tif',
#  'img641.tif',
#  'img305.tif',
#  'img452.tif',
#  'img171.tif',
#  'img315.tif',
#  'img440.tif',
#  'img920.tif',
#  'img643.tif',
#  'img416.tif',
#  'img634.tif',
#  'img489.tif',
#  'img886.tif',
#  'img556.tif',
#  'img357.tif',
#  'img211.tif',
#  'img677.tif',
#  'img915.tif',
#  'img179.tif',
#  'img84.tif',
#  'img861.tif',
#  'img139.tif',
#  'img415.tif',
#  'img547.tif',
#  'img1010.tif',
#  'img918.tif',
#  'img236.tif',
#  'img518.tif',
#  'img175.tif',
#  'img505.tif',
#  'img826.tif',
#  'img573.tif',
#  'img979.tif',
#  'img389.tif',
#  'img488.tif',
#  'img475.tif',
#  'img582.tif',
#  'img147.tif',
#  'img83.tif',
#  'img735.tif',
#  'img604.tif',
#  'img204.tif',
#  'img368.tif',
#  'img852.tif',
#  'img727.tif',
#  'img441.tif',
#  'img360.tif',
#  'img448.tif',
#  'img474.tif',
#  'img241.tif',
#  'img504.tif',
#  'img887.tif',
#  'img390.tif',
#  'img485.tif',
#  'img317.tif',
#  'img637.tif',
#  'img472.tif',
#  'img446.tif',
#  'img536.tif',
#  'img198.tif',
#  'img583.tif',
#  'img1009.tif',
#  'img206.tif',
#  'img396.tif',
#  'img234.tif',
#  'img209.tif',
#  'img377.tif',
#  'img398.tif',
#  'img326.tif',
#  'img579.tif',
#  'img758.tif',
#  'img257.tif',
#  'img514.tif',
#  'img769.tif',
#  'img392.tif',
#  'img423.tif',
#  'img768.tif',
#  'img453.tif',
#  'img507.tif',
#  'img205.tif',
#  'img200.tif',
#  'img508.tif',
#  'img555.tif',
#  'img821.tif',
#  'img509.tif',
#  'img647.tif',
#  'img760.tif',
#  'img174.tif',
#  'img702.tif',
#  'img764.tif',
#  'img112.tif',
#  'img792.tif',
#  'img238.tif',
#  'img588.tif',
#  'img728.tif',
#  'img767.tif',
#  'img243.tif',
#  'img586.tif',
#  'img329.tif',
#  'img558.tif',
#  'img578.tif',
#  'img82.tif',
#  'img316.tif',
#  'img726.tif',
#  'img352.tif',
#  'img495.tif',
#  'img694.tif',
#  'img675.tif',
#  'img549.tif',
#  'img306.tif',
#  'img350.tif',
#  'img553.tif',
#  'img618.tif',
#  'img106.tif',
#  'img333.tif',
#  'img381.tif',
#  'img349.tif',
#  'img227.tif',
#  'img738.tif',
#  'img231.tif',
#  'img704.tif',
#  'img729.tif',
#  'img347.tif',
#  'img695.tif',
#  'img648.tif',
#  'img176.tif',
#  'img539.tif',
#  'img242.tif',
#  'img601.tif',
#  'img825.tif',
#  'img765.tif',
#  'img506.tif',
#  'img882.tif',
#  'img172.tif',
#  'img369.tif',
#  'img919.tif',
#  'img107.tif',
#  'img203.tif',
#  'img286.tif',
#  'img699.tif',
#  'img418.tif',
#  'img288.tif',
#  'img202.tif',
#  'img884.tif',
#  'img757.tif',
#  'img612.tif',
#  'img527.tif',
#  'img828.tif',
#  'img318.tif',
#  'img890.tif',
#  'img143.tif',
#  'img292.tif',
#  'img460.tif',
#  'img297.tif',
#  'img464.tif',
#  'img265.tif',
#  'img332.tif',
#  'img259.tif',
#  'img476.tif',
#  'img823.tif',
#  'img393.tif',
#  'img363.tif',
#  'img706.tif',
#  'img770.tif',
#  'img946.tif',
#  'img921.tif',
#  'img515.tif',
#  'img367.tif',
#  'img709.tif',
#  'img678.tif',
#  'img345.tif',
#  'img853.tif',
#  'img254.tif',
#  'img108.tif',
#  'img264.tif',
#  'img524.tif',
#  'img666.tif',
#  'img48.tif',
#  'img859.tif']

# %%
# check for partial tiles
imgD1 = np.zeros((T,2), dtype=int)

for i in range(T):
    tileLoad = gdal.Open(os.path.join(base_dirP, tiles[i]), gdal.GA_ReadOnly)
    tileAr = np.array(tileLoad.GetRasterBand(1).ReadAsArray())
    imgD1[i,0] = tileAr.shape[0]
    imgD1[i,1] = tileAr.shape[1]

# %%
# check for partial tiles

imgFlag = np.zeros((T), dtype=int)

for i in range(T):
    if imgD1[i,0] < 256 or imgD1[i,1] < 256:
        imgFlag[i] = 1
    else:
        imgFlag[i] = 0

imgTable = np.zeros((T,1), dtype=int)
for i in range(T):
    imgTable[i,0] = imgFlag[i]

# %%
def load_stack_rgb_tile(shape, dtype, img_dir, file, imgFlag):
    stack = np.zeros(shape = shape, dtype = dtype)
    for i in range(shape[0]):
        image_path = os.path.join(img_dir, file[i])
        # subsets for rgb bands only
        imageT = gdal.Open(os.path.join(base_dirP, tiles[i]), gdal.GA_ReadOnly)
        if imgFlag[i,0] == 1:
            print("nullified", image_path)
            stack[i,:,:,:] = np.nan
        else:
            for k in (1, 2, 3):
                stack[i, :, :, k-1] = np.array(imageT.GetRasterBand(k).ReadAsArray())
    return stack

# %%
tiles_milk = load_stack_rgb_tile((T,256,256,3), np.float32, base_dirP, tiles,imgTable)
# Out:
# nullified /media/hkropp/research/milkweed/tile_07_22_22/img1041.tif
# nullified /media/hkropp/research/milkweed/tile_07_22_22/img558.tif
# nullified /media/hkropp/research/milkweed/tile_07_22_22/img527.tif

# %%
plt.imshow(tiles_milk[100,:,:,2])

# %%
def save_predict_milk( nImg, xdim,ydim, img_dir, prefix, orig_dir, file):
    for i in range(T):
        image_path = make_path(img_dir, prefix, i + 1)
        tilepath = os.path.join(img_dir, file[i])
        orig_ds = gdal.Open(tilepath)
        gt = orig_ds.GetGeoTransform()
        pt = orig_ds.GetProjection()
        outTM = driver.Create(image_path, xsize=xdim, ysize=ydim,
                             bands=1, eType=gdal.GDT_Float32)
        outTM.SetGeoTransform(gt)
        outTM.SetProjection(pt)
        outBandTreeM = outTM.GetRasterBand(1)
        outBandTreeM.WriteArray(Y_all[i, :, :, 3])
        outBandTreeM.SetNoDataValue(np.nan)
        outBandTreeM.FlushCache()
        outBandTreeM = None
        outTreeM = None
